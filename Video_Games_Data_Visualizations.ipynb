# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['image.cmap']='plasma'

# %%
df = pd.read_csv('E:/Sonu/ML_Algorithms/video-game-sales-with-ratings/Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.dropna()
# Out:
#                                     Name Platform  Year_of_Release     Genre  \
# 0                             Wii Sports      Wii           2006.0    Sports
# 2                         Mario Kart Wii      Wii           2008.0    Racing
# 3                      Wii Sports Resort      Wii           2009.0    Sports
# 6                  New Super Mario Bros.       DS           2006.0  Platform
# 7                               Wii Play      Wii           2006.0      Misc
# ...                                  ...      ...              ...       ...
# 16667         E.T. The Extra-Terrestrial      GBA           2001.0    Action
# 16677     Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
# 16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 16700                             Breach       PC           2011.0   Shooter
# 16706            STORM: Frontline Nation       PC           2011.0  Strategy
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
 df.dropna(inplace = True)

# %%
 df['Year_of_Release']
# Out:
# array([2006., 2008., 2009., 2005., 2007., 2010., 2013., 2004., 2002.,
#        2001., 2011., 2012., 2014., 1997., 1999., 2015., 2016., 2003.,
#        1998., 1996., 2000., 1994., 1985., 1992., 1988.])

# %%
df['Year_of_Release'] = df['Year_of_Release'].astype('int64')

# %%
df['User_Score'] = df['User_Score'].astype('float64')
df['User_Count'] = df['User_Count'].astype('int64')

# %% [markdown]
# DataFrame Plot

# %%
df[[x for x in df.columns if 'Sales' in x] + 
   ['Year_of_Release']].groupby('Year_of_Release').sum().plot();
#Picking up sales columns

# %%
df[[x for x in df.columns if 'Sales' in x] + ['Year_of_Release']].groupby(['Year_of_Release']).sum().plot(kind = 'bar' , rot = 45,figsize =(15,5))

# %%
df[['User_Count'] + ['Year_of_Release']].groupby('Year_of_Release').sum().plot()

# %%
df[['User_Count']+['Genre']].groupby('Genre').sum().plot(kind = 'bar' , rot = 45)

# %% [markdown]
# Seaborn Plots

# %%
#Pair Plots
# %config InlineBackend.figure_format = 'png'
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'Critic_Count', 
                 'User_Score', 'User_Count']])

# %%
#DistPlot - Distribution of a variable

sns.distplot(df['Critic_Score'])

# %%
#Jointplot - relationship between two variables 
sns.jointplot(x='Critic_Score',y='User_Score',data= df , kind = 'scatter')

# %%
top_plt = df['Platform'].value_counts().sort_values(ascending = False).head(4).index.values
sns.boxplot(y='Platform',x = 'Critic_Score',data=df[df['Platform'].isin(top_plt)])

# %%
#Heatmap() - distribution of Numerical feature over two Categorical features.

platform_genre_tables = df.pivot_table( index = 'Platform',columns = 'Genre',values = 'Global_Sales',aggfunc=sum).fillna(0).applymap(float)

# %%
print(platform_genre_tables)
# Out:
# Genre     Action  Adventure  Fighting    Misc  Platform  Puzzle  Racing  \
# Platform
# 3DS        30.81       2.00      2.63    4.48     27.61    2.63   13.89
# DC          0.00       1.33      0.56    0.00      0.12    0.00    0.20
# DS         42.43       8.83      3.37   68.82     55.02   50.50   29.93
# GBA        23.21       4.54      3.28    8.59     40.36    5.47   12.60
# GC         29.99       4.56     15.81   12.72     24.67    3.31   11.09
# PC         25.45       1.42      0.13    3.02      0.46    0.19    3.18
# PS         54.93       1.10     18.91    5.66     18.92    0.26   34.17
# PS2       238.73      10.74     64.72   38.70     52.34    3.97  127.17
# PS3       262.38      16.18     47.83   26.59     20.91    0.40   62.17
# PS4        76.92       3.09      6.86    2.70      6.16    0.03    9.08
# PSP        43.92       2.81     12.36    5.09     10.84    2.04   27.88
# PSV         9.53       1.28      1.91    1.81      2.49    0.12    1.00
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(platform_genre_tables,annot = True, fmt = '.1f',linewidth=.5)
#plt.set_ylim(len(platform_genre_tables)-0.5, -0.5)

#Top and bottom row cut-off is known matplotlb Bug

# %% [markdown]
# Plotly : Interactive Plots with Details

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
years_df = df.groupby('Year_of_Release')[['Global_Sales']].sum().join(df.groupby(['Year_of_Release'])[['Name']].count())

# %%
years_df.columns = ['Global_Sales','Number_of_Games']
years_df
# Out:
#                  Global_Sales  Number_of_Games
# Year_of_Release
# 1985                     0.03                1
# 1988                     0.03                1
# 1992                     0.03                1
# 1994                     1.27                1
# 1996                    20.10                7
# 1997                    35.01               13
# 1998                    43.18               25
# 1999                    51.17               30
# 2000                    81.24              102
# 2001                   253.88              256
# 2002                   288.84              455
# 2003                   255.35              498
# 2004                   321.78              476
# 2005                   334.32              562
# 2006                   416.72              528
# 2007                   456.23              590
# 2008                   489.12              592
# 2009                   459.85              550
# 2010                   412.96              429
# ...

# %%
# Tracing line for Global Sales 
trace0 = go.Scatter( x = years_df.index, y = years_df['Global_Sales'],name = 'Global_Sales')

#Tracing line for Number of games released
trace1 = go.Scatter(x = years_df.index , y = years_df['Number_of_Games'],name = 'Number of Games Released')

data = [trace0 , trace1]

layout = {'title':'Statistics for Video games'}

fig = go.Figure(data=data , layout = layout)
iplot(fig,show_link=False)
# Out:
# <div>
#
#
#             <div id="448ba294-3392-4171-947b-3564ff1297af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("448ba294-3392-4171-947b-3564ff1297af")) {
#                     Plotly.newPlot(
#                         '448ba294-3392-4171-947b-3564ff1297af',
# ...

# %%
plotly.offline.plot(fig, filename='years_stats.html', show_link=False);

# %% [markdown]
# BAR CHARTS

# %%
platform_df = df.groupby(['Platform'])[['Global_Sales']].sum().join(df.groupby(['Platform'])[['Name']].count())

# %%
platform_df
# Out:
#           Global_Sales  Name
# Platform
# 3DS             123.23   155
# DC                4.55    14
# DS              382.33   464
# GBA             131.75   237
# GC              159.42   348
# PC              187.12   651
# PS              206.55   150
# PS2             945.97  1140
# PS3             784.30   769
# PS4             243.03   239
# PSP             187.92   390
# PSV              30.88   118
# Wii             658.98   479
# WiiU             66.08    89
# X360            853.30   858
# XB              212.07   565
# XOne            129.57   159

# %%
platform_df.columns = ['Global_Sales','Number_of_Games']
platform_df.sort_values('Global_Sales',ascending = False , inplace = True)

# %%
#Bar graph by global Sales

trace0 = go.Bar(x= platform_df.index , y = platform_df['Global_Sales'],name = 'Global Sales')
trace1 = go.Bar(x = platform_df.index , y = platform_df['Number_of_Games'], name = 'Number_of_Games_Releases')
data = [trace0,trace1]
layout= {'title':'Market Share by gaming platform'}
fig = go.Figure(data=data,layout=layout)
iplot(fig,show_link=False)
# Out:
# <div>
#
#
#             <div id="8f69ad37-1cb4-4b8d-a542-59990cd2440e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f69ad37-1cb4-4b8d-a542-59990cd2440e")) {
#                     Plotly.newPlot(
#                         '8f69ad37-1cb4-4b8d-a542-59990cd2440e',
# ...

# %% [markdown]
# Boxplots by Plotly

# %%
data = []

for genre in df.Genre.unique():
    data.append( go.Box(y = df[df.Genre == genre].Critic_Score , name = genre))


iplot(data,show_link=False)
# Out:
# <div>
#
#
#             <div id="d7ccc2ca-e80c-4423-9ace-e9dc665f09ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d7ccc2ca-e80c-4423-9ace-e9dc665f09ab")) {
#                     Plotly.newPlot(
#                         'd7ccc2ca-e80c-4423-9ace-e9dc665f09ab',
# ...
